# %% [markdown]
# <a href="https://colab.research.google.com/github/AnvithAnvi/Forevvpage/blob/main/EDA_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Death Percentage by Year

# %% [markdown]
# ### 1) Why this project ?

# %% [markdown]
# This EDA project is to analyse the dataset. This project is to analyse the Death Percentage by year.

# %% [markdown]
# ### 2) Which domain it belongs to ?

# %% [markdown]
# It belongs to Death Domain.

# %% [markdown]
# ### 3) Information about Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/EDA Project/Death percentage by year.csv")
df
# Out:
#        Region Code                      Region Name Country Code  \
# 0               EU                           Europe          ALB
# 1               EU                           Europe          ALB
# 2               EU                           Europe          ALB
# 3               EU                           Europe          ALB
# 4               EU                           Europe          ALB
# ...            ...                              ...          ...
# 294982         NAC  North America and the Caribbean          USA
# 294983         NAC  North America and the Caribbean          USA
# 294984         NAC  North America and the Caribbean          USA
# 294985         NAC  North America and the Caribbean          USA
# 294986         NAC  North America and the Caribbean          USA
#
#                     Country Name  Year     Sex  Unnamed: 6  Age Group  \
# 0                        Albania  1987     All         NaN      [All]
# ...

# %%
df.shape
# Out:
# (294987, 12)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294987 entries, 0 to 294986
# Data columns (total 12 columns):
#  #   Column                                                       Non-Null Count   Dtype
# ---  ------                                                       --------------   -----
#  0   Region Code                                                  294987 non-null  object
#  1   Region Name                                                  294987 non-null  object
#  2   Country Code                                                 294987 non-null  object
#  3   Country Name                                                 294987 non-null  object
#  4   Year                                                         294987 non-null  int64
#  5   Sex                                                          294987 non-null  object
#  6   Age group code                                               294987 non-null  object
# ...

# %%
df.describe()
# Out:
#                 Year         Number  \
# count  294987.000000  293667.000000
# mean     1992.364419     892.081248
# std        17.846092    5840.069706
# min      1950.000000       0.000000
# 25%      1979.000000      12.000000
# 50%      1995.000000      81.000000
# 75%      2007.000000     345.000000
# max      2020.000000  368365.000000
#
#        Percentage of cause-specific deaths out of total deaths  \
# count                                      285256.000000
# mean                                           19.673508
# std                                            21.228881
# min                                             0.000000
# 25%                                             3.130562
# 50%                                             9.869443
# 75%                                            32.456140
# max                                           100.000000
#
#        Age-standardized death rate per 100 000 standard population  \
# ...

# %%
df.isnull()
# Out:
#         Region Code  Region Name  Country Code  Country Name   Year    Sex  \
# 0             False        False         False         False  False  False
# 1             False        False         False         False  False  False
# 2             False        False         False         False  False  False
# 3             False        False         False         False  False  False
# 4             False        False         False         False  False  False
# ...             ...          ...           ...           ...    ...    ...
# 294982        False        False         False         False  False  False
# 294983        False        False         False         False  False  False
# 294984        False        False         False         False  False  False
# 294985        False        False         False         False  False  False
# 294986        False        False         False         False  False  False
#
#         Age group code  Age Group  Number  \
# ...

# %%
df.isnull().sum()
# Out:
# Region Code                                                         0
# Region Name                                                         0
# Country Code                                                        0
# Country Name                                                        0
# Year                                                                0
# Sex                                                                 0
# Age group code                                                      0
# Age Group                                                           0
# Number                                                           1320
# Percentage of cause-specific deaths out of total deaths          9731
# Age-standardized death rate per 100 000 standard population    281388
# Death rate per 100 000 population                               24972
# dtype: int64

# %%
null = df.isnull().sum()/df.shape[0]*100
null.plot(kind='bar')
plt.title("% of Null values in each Column")
plt.show()

# %%
df.duplicated().sum()
# Out:
# 0
